# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = open("d_tune.txt")
ar = file.readlines()
c = 0
#hray = []
for x in ar:
    line = x.split(" ")
    sline = np.array(line)
    nline = sline.astype(np.float)
    
    plt.figure(figsize=(15,5))
    plt.plot(nline, 'k')
    #if c == 0:
    #    hray = nline
    #else:
    #    hray = np.append(hray, nline)
    c += 1

#plt.figure(figsize=(15,5))
#plt.plot(hray, 'k')
# Out:
# /home/wit/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # Remove the CWD from sys.path while we load stuff.

# %%
m = 0
mi = 0
for x in range(len(hray)):
    if hray[x] > m:
        m = hray[x]
        mi = x
print(m)
print(mi)
# Out:
# 1.0
# 53
